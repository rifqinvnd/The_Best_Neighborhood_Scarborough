# %% [markdown]
# ### Toronto Neighborhood Analysis
# This notebook contain my analysis on Toronto neighborhood
#
# First, import some library and get the url using soup

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(url.content, 'lxml')

# %% [markdown]
# Create a dataframe

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['Postal Code'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})
df.head()
# Out:
#   Postal Code           Borough                      Neighborhood
# 0         M3A        North York                         Parkwoods
# 1         M4A        North York                  Victoria Village
# 2         M5A  Downtown Toronto         Regent Park, Harbourfront
# 3         M6A        North York  Lawrence Manor, Lawrence Heights
# 4         M7A      Queen's Park     Ontario Provincial Government

# %% [markdown]
# Now we'll get the unique postal code available at the dataframe.

# %%
len(df['Postal Code'].unique())
# Out:
# 103

# %% [markdown]
# Then, we use the geocoder to make the postal code coordinates

# %%
import geocoder

geo_csv = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv'
geo_df = pd.read_csv(geo_csv)
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Let's check if both dataframe already on the same shape

# %%
df.shape
# Out:
# (103, 3)

# %%
geo_df.shape
# Out:
# (103, 3)

# %% [markdown]
# Combine both dataframe using join function

# %%
df_com = df.join(geo_df.set_index('Postal Code'), on='Postal Code')
df_com
# Out:
#     Postal Code                Borough  \
# 0           M3A             North York
# 1           M4A             North York
# 2           M5A       Downtown Toronto
# 3           M6A             North York
# 4           M7A           Queen's Park
# ..          ...                    ...
# 98          M8X              Etobicoke
# 99          M4Y       Downtown Toronto
# 100         M7Y  East Toronto Business
# 101         M8Y              Etobicoke
# 102         M8Z              Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ...

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

toronto_merged_nonan = toronto_merged.dropna(subset=['Cluster Labels'])

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged_nonan['Latitude'], toronto_merged_nonan['Longitude'], toronto_merged_nonan['Neighborhood'], toronto_merged_nonan['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Now we examine the 1st till the 5th cluster

# %% [markdown]
# 1st Cluster

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 0, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0         North York             0.0     Food & Drink Shop
# 16              York             0.0                  Park
# 21              York             0.0                  Park
# 40        North York             0.0                  Park
# 52        North York             0.0                  Park
# 61   Central Toronto             0.0                  Park
# 66        North York             0.0                  Park
# 68   Central Toronto             0.0                  Park
# 77         Etobicoke             0.0                  Park
# 85       Scarborough             0.0                  Park
# 91  Downtown Toronto             0.0                  Park
# 98         Etobicoke             0.0                 River
#
#          2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0         Fast Food Restaurant                  Park   Dumpling Restaurant
# ...

# %% [markdown]
# 2nd Cluster

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 1, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 57   North York             1.0        Baseball Field           Yoga Studio
# 101   Etobicoke             1.0        Baseball Field           Yoga Studio
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 57    Dumpling Restaurant   Distribution Center               Dog Run
# 101   Dumpling Restaurant   Distribution Center               Dog Run
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 57       Doner Restaurant            Donut Shop             Drugstore
# 101      Doner Restaurant            Donut Shop             Drugstore
#
#            9th Most Common Venue 10th Most Common Venue
# 57   Eastern European Restaurant                  Diner
# 101  Eastern European Restaurant                  Diner

# %% [markdown]
# 3rd Cluster

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 2, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 1               North York             2.0          Intersection
# 2         Downtown Toronto             2.0           Coffee Shop
# 3               North York             2.0        Clothing Store
# 4             Queen's Park             2.0           Coffee Shop
# 6              Scarborough             2.0  Fast Food Restaurant
# ..                     ...             ...                   ...
# 96        Downtown Toronto             2.0           Coffee Shop
# 97        Downtown Toronto             2.0           Coffee Shop
# 99        Downtown Toronto             2.0           Coffee Shop
# 100  East Toronto Business             2.0    Light Rail Station
# 102              Etobicoke             2.0        Hardware Store
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1             Pizza Place     French Restaurant           Coffee Shop
# ...

# %% [markdown]
# 4th Cluster

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 3, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 12      Scarborough             3.0                   Bar
# 53       North York             3.0          Home Service
# 62  Central Toronto             3.0          Home Service
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12          Home Service           Yoga Studio             Drugstore
# 53            Food Truck        Baseball Field           Yoga Studio
# 62                Garden           Yoga Studio             Drugstore
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 12        Discount Store   Distribution Center               Dog Run
# 53   Distribution Center               Dog Run      Doner Restaurant
# 62                 Diner        Discount Store   Distribution Center
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12      Doner Restaurant            Donut Shop    Dumpling Restaurant
# ...

# %% [markdown]
# 5th Cluster

# %%
toronto_merged_nonan.loc[toronto_merged_nonan['Cluster Labels'] == 4, toronto_merged_nonan.columns[[1] + list(range(5, toronto_merged_nonan.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 32  Scarborough             4.0         Grocery Store            Playground
# 46   North York             4.0         Grocery Store                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 32           Yoga Studio             Drugstore                 Diner
# 46                  Bank         Shopping Mall           Yoga Studio
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 32        Discount Store   Distribution Center               Dog Run
# 46             Drugstore        Discount Store   Distribution Center
#
#    9th Most Common Venue 10th Most Common Venue
# 32      Doner Restaurant             Donut Shop
# 46               Dog Run       Doner Restaurant
